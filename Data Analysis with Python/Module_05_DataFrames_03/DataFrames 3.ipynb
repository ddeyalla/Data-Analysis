# %%
import pandas as pd

import numpy as np

# %%
df = pd.read_csv("D:\python\Data Analysis with Python\#Udemy\Pandas\jamesbond.csv")

df.head(3)
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2

# %% [markdown]
# # The .set_index() and .reset_index() Methods

# %%
df.set_index(["Film"], inplace = True)

# %%
df.head()
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %%
df.reset_index(drop = False, inplace = True)
df.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %% [markdown]
# # Retrieve Rows by Index Label with .loc[ ]

# %%
df = pd.read_csv("D:\python\Data Analysis with Python\#Udemy\Pandas\jamesbond.csv")

df.head(3)
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2

# %%
df.set_index("Film", inplace = True)

# %%
df.sort_index(inplace = True)
df.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
df.loc["Diamonds Are Forever"] #extraction process
df.loc["Casino Royale"]
# Out:
#                Year         Actor         Director  Box Office  Budget  \
# Film
# Casino Royale  2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale  1967   David Niven       Ken Hughes       315.0    85.0
#
#                Bond Actor Salary
# Film
# Casino Royale                3.3
# Casino Royale                NaN

# %%
df.loc["Casino Royale" : "Die Another Day"]
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
df.loc[ : "Casino Royale"]
df.loc["Casino Royale" :]
# Out:
#                                  Year           Actor            Director  \
# Film
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
df.loc[["Octopussy", "Casino Royale"]]
# Out:
#                Year         Actor         Director  Box Office  Budget  \
# Film
# Octopussy      1983   Roger Moore        John Glen       373.8    53.9
# Casino Royale  2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale  1967   David Niven       Ken Hughes       315.0    85.0
#
#                Bond Actor Salary
# Film
# Octopussy                    7.8
# Casino Royale                3.3
# Casino Royale                NaN

# %%
"Gold Bond" in df.index
# Out:
# False

# %% [markdown]
# # Retrieve Rows by Index Position with .iloc[]

# %% [markdown]
# Purely integer-location based indexing for selection by position.
#
# .iloc[] is primarily integer position based (from 0 to length-1 of the axis), but may also be used with a boolean array.

# %%
df = pd.read_csv("D:\python\Data Analysis with Python\#Udemy\Pandas\jamesbond.csv")

df.head(3)
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2

# %%
df.loc[15]
df.iloc[15]
df.loc[:4]
df.iloc[:4]
df.iloc[20:]
# Out:
#                        Film  Year           Actor         Director  \
# 20  The World Is Not Enough  1999  Pierce Brosnan    Michael Apted
# 21          Die Another Day  2002  Pierce Brosnan     Lee Tamahori
# 22            Casino Royale  2006    Daniel Craig  Martin Campbell
# 23        Quantum of Solace  2008    Daniel Craig     Marc Forster
# 24                  Skyfall  2012    Daniel Craig       Sam Mendes
# 25                  Spectre  2015    Daniel Craig       Sam Mendes
#
#     Box Office  Budget  Bond Actor Salary
# 20       439.5   158.3               13.5
# 21       465.4   154.2               17.9
# 22       581.5   145.3                3.3
# 23       514.2   181.4                8.1
# 24       943.5   170.2               14.5
# 25       726.7   206.3                NaN

# %%
df = pd.read_csv("D:\python\Data Analysis with Python\#Udemy\Pandas\jamesbond.csv", index_col = "Film")
df.sort_index(inplace = True)
df.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
df.iloc[1] #requires index irresepective of the value in it
# df.loc[1] # will give error since loc needs the index value
# Out:
# Year                            2006
# Actor                   Daniel Craig
# Director             Martin Campbell
# Box Office                     581.5
# Budget                         145.3
# Bond Actor Salary                3.3
# Name: Casino Royale, dtype: object

# %% [markdown]
# # The Catch-All .ix[ ] Method # Depricated

# %% [markdown]
# A primarily label-location based indexer, with integer position fallback.
#
# Warning: Starting in 0.20.0, the .ix indexer is deprecated, in favor of the more strict .iloc and .loc indexers.
#
# .ix[] supports mixed integer and label based access. It is primarily label based, but will fall back to integer positional access unless the corresponding axis is of integer type.
#
# .ix is the most general indexer and will support any of the inputs in .loc and .iloc. .ix also supports floating point label schemes. .ix is exceptionally useful when dealing with mixed positional and label based hierarchical indexes.
#
# However, when an axis is integer based, ONLY label based access and not positional access is supported. Thus, in such cases, it’s usually better to be explicit and use .iloc or .loc.

# %%
df.ix["Casino Royale"]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#                Year         Actor         Director  Box Office  Budget  \
# Film
# Casino Royale  2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale  1967   David Niven       Ken Hughes       315.0    85.0
#
#                Bond Actor Salary
# Film
# Casino Royale                3.3
# Casino Royale                NaN

# %% [markdown]
# # Second Arguments to .loc[], .iloc[], and .ix[] Methods

# %%
df = pd.read_csv("D:\python\Data Analysis with Python\#Udemy\Pandas\jamesbond.csv", index_col = "Film")
df.sort_index(inplace = True)
df.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
df.loc[["Moonraker", "Casino Royale"], "Actor"]
# Out:
# Film
# Moonraker         Roger Moore
# Casino Royale    Daniel Craig
# Casino Royale     David Niven
# Name: Actor, dtype: object

# %%
df.iloc[[1,2], 2:5] #use numerical values
# Out:
#                       Director  Box Office  Budget
# Film
# Casino Royale  Martin Campbell       581.5   145.3
# Casino Royale       Ken Hughes       315.0    85.0

# %% [markdown]
# # Set New Values for a Specific Cell or Row

# %%
df.loc["Dr. No", "Actor"] = "Sir Sean Connery"

# %%
df.loc["Dr. No", "Actor"]
# Out:
# 'Sir Sean Connery'

# %%
df.loc["Dr. No", ["Box Office", "Budget", "Bond Actor Salary"]]
# Out:
# Box Office           449
# Budget                 7
# Bond Actor Salary    0.7
# Name: Dr. No, dtype: object

# %%
df.loc["Dr. No", ["Box Office", "Budget", "Bond Actor Salary"]] = [449.0, 7, 0.7]

# %% [markdown]
# # Set Multiple Values in DataFrame

# %%
mask = df["Actor"] == "Sean Connery"

# %%
df.loc[mask]
# Out:
#                        Year         Actor        Director  Box Office  Budget  \
# Film
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
#
#                        Bond Actor Salary
# Film
# Diamonds Are Forever                 5.8
# From Russia with Love                1.6
# Goldfinger                           3.2
# Never Say Never Again                NaN
# Thunderball                          4.7
# You Only Live Twice                  4.4

# %% [markdown]
# # Rename Index Labels or Columns in a DataFrame

# %%
df = pd.read_csv("D:\python\Data Analysis with Python\#Udemy\Pandas\jamesbond.csv", index_col = "Film")
df.sort_index(inplace = True)
df.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
df.rename(columns = {"Year"  : "Release Date"}, inplace = True)

# %%
df.rename(columns = {"Box Office"  : "Revenue"}, inplace = True)

# %%
df.head()
# Out:
#                       Release Date           Actor         Director  Revenue  \
# Film
# A View to a Kill              1985     Roger Moore        John Glen    275.2
# Casino Royale                 2006    Daniel Craig  Martin Campbell    581.5
# Casino Royale                 1967     David Niven       Ken Hughes    315.0
# Diamonds Are Forever          1971    Sean Connery     Guy Hamilton    442.5
# Die Another Day               2002  Pierce Brosnan     Lee Tamahori    465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
#index label can be changed using the index parameters in the rename function

# %% [markdown]
# # Delete Rows or Columns from a DataFrame
# ## drop / pop / del

# %%
df.drop(index = "A View to a Kill", columns = "Budget")
# Out:
#                                  Release Date           Actor  \
# Film
# Casino Royale                            2006    Daniel Craig
# Casino Royale                            1967     David Niven
# Diamonds Are Forever                     1971    Sean Connery
# Die Another Day                          2002  Pierce Brosnan
# Dr. No                                   1962    Sean Connery
# For Your Eyes Only                       1981     Roger Moore
# From Russia with Love                    1963    Sean Connery
# GoldenEye                                1995  Pierce Brosnan
# Goldfinger                               1964    Sean Connery
# Licence to Kill                          1989  Timothy Dalton
# Live and Let Die                         1973     Roger Moore
# Moonraker                                1979     Roger Moore
# Never Say Never Again                    1983    Sean Connery
# Octopussy                                1983     Roger Moore
# ...

# %%
df.head()
# Out:
#                       Release Date           Actor         Director  Revenue  \
# Film
# A View to a Kill              1985     Roger Moore        John Glen    275.2
# Casino Royale                 2006    Daniel Craig  Martin Campbell    581.5
# Casino Royale                 1967     David Niven       Ken Hughes    315.0
# Diamonds Are Forever          1971    Sean Connery     Guy Hamilton    442.5
# Die Another Day               2002  Pierce Brosnan     Lee Tamahori    465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
actor = df.pop("Actor")

# %%
actor
# Out:
# Film
# A View to a Kill                      Roger Moore
# Casino Royale                        Daniel Craig
# Casino Royale                         David Niven
# Diamonds Are Forever                 Sean Connery
# Die Another Day                    Pierce Brosnan
# Dr. No                               Sean Connery
# For Your Eyes Only                    Roger Moore
# From Russia with Love                Sean Connery
# GoldenEye                          Pierce Brosnan
# Goldfinger                           Sean Connery
# Licence to Kill                    Timothy Dalton
# Live and Let Die                      Roger Moore
# Moonraker                             Roger Moore
# Never Say Never Again                Sean Connery
# Octopussy                             Roger Moore
# On Her Majesty's Secret Service    George Lazenby
# Quantum of Solace                    Daniel Craig
# Skyfall                              Daniel Craig
# Spectre                              Daniel Craig
# ...

# %% [markdown]
# # Create Random Sample with the .sample() Method

# %%
df_sample = df.sample(axis = 1)

# %%
import matplotlib.pyplot as plt
from pylab import rcParams
rcParams['figure.figsize'] = 10, 5

# %%
df_sample
# Out:
#                                  Revenue
# Film
# A View to a Kill                   275.2
# Casino Royale                      581.5
# Casino Royale                      315.0
# Diamonds Are Forever               442.5
# Die Another Day                    465.4
# Dr. No                             448.8
# For Your Eyes Only                 449.4
# From Russia with Love              543.8
# GoldenEye                          518.5
# Goldfinger                         820.4
# Licence to Kill                    250.9
# Live and Let Die                   460.3
# Moonraker                          535.0
# Never Say Never Again              380.0
# Octopussy                          373.8
# On Her Majesty's Secret Service    291.5
# Quantum of Solace                  514.2
# Skyfall                            943.5
# Spectre                            726.7
# The Living Daylights               313.5
# The Man with the Golden Gun        334.0
# The Spy Who Loved Me               533.0
# ...

# %%
plt.plot(df_sample.index, df_sample.values)
plt.xlabel("Revenue")
plt.ylabel("film")
# Out:
# Text(0, 0.5, 'film')

# %% [markdown]
# # The .nsmallest() and .nlargest() Methods

# %%
df = pd.read_csv("D:\python\Data Analysis with Python\#Udemy\Pandas\jamesbond.csv", index_col = "Film")
df.sort_index(inplace = True)
df.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
df.sort_values("Box Office",ascending = False).head(3)
# Out:
#              Year         Actor       Director  Box Office  Budget  \
# Film
# Skyfall      2012  Daniel Craig     Sam Mendes       943.5   170.2
# Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
# Goldfinger   1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#              Bond Actor Salary
# Film
# Skyfall                   14.5
# Thunderball                4.7
# Goldfinger                 3.2

# %%
df.nlargest(n = 3, columns = "Box Office")
# Out:
#              Year         Actor       Director  Box Office  Budget  \
# Film
# Skyfall      2012  Daniel Craig     Sam Mendes       943.5   170.2
# Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
# Goldfinger   1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#              Bond Actor Salary
# Film
# Skyfall                   14.5
# Thunderball                4.7
# Goldfinger                 3.2

# %%
df.sort_values("Box Office",ascending = True).head(3)
# Out:
#                                  Year           Actor       Director  \
# Film
# Licence to Kill                  1989  Timothy Dalton      John Glen
# A View to a Kill                 1985     Roger Moore      John Glen
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Licence to Kill                       250.9    56.7                7.9
# A View to a Kill                      275.2    54.5                9.1
# On Her Majesty's Secret Service       291.5    37.3                0.6

# %%
df.nsmallest(n = 3, columns = "Box Office")
# Out:
#                                  Year           Actor       Director  \
# Film
# Licence to Kill                  1989  Timothy Dalton      John Glen
# A View to a Kill                 1985     Roger Moore      John Glen
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Licence to Kill                       250.9    56.7                7.9
# A View to a Kill                      275.2    54.5                9.1
# On Her Majesty's Secret Service       291.5    37.3                0.6

# %% [markdown]
# # Filtering with the .where() Method

# %%
mask = df["Actor"] == "Sean Connery"

# %%
df[mask]
# Out:
#                        Year         Actor        Director  Box Office  Budget  \
# Film
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# Dr. No                 1962  Sean Connery   Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
#
#                        Bond Actor Salary
# Film
# Diamonds Are Forever                 5.8
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Never Say Never Again                NaN
# Thunderball                          4.7
# ...

# %%
df.where(mask)
# Out:
#                                    Year         Actor        Director  \
# Film
# A View to a Kill                    NaN           NaN             NaN
# Casino Royale                       NaN           NaN             NaN
# Casino Royale                       NaN           NaN             NaN
# Diamonds Are Forever             1971.0  Sean Connery    Guy Hamilton
# Die Another Day                     NaN           NaN             NaN
# Dr. No                           1962.0  Sean Connery   Terence Young
# For Your Eyes Only                  NaN           NaN             NaN
# From Russia with Love            1963.0  Sean Connery   Terence Young
# GoldenEye                           NaN           NaN             NaN
# Goldfinger                       1964.0  Sean Connery    Guy Hamilton
# Licence to Kill                     NaN           NaN             NaN
# Live and Let Die                    NaN           NaN             NaN
# ...

# %% [markdown]
# # The .query() Method

# %%
df.query()

# %%
df.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
df.columns = [column_name.replace(" ", "_") for column_name in df.columns]

# %%
df.query('Actor == "Sean Connery"') #extraction with Query string
# Out:
#                        Year         Actor        Director  Box_Office  Budget  \
# Film
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# Dr. No                 1962  Sean Connery   Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
#
#                        Bond_Actor_Salary
# Film
# Diamonds Are Forever                 5.8
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Never Say Never Again                NaN
# Thunderball                          4.7
# ...

# %%
df[df["Actor"] == "Sean Connery"] #regular extraction
# Out:
#                        Year         Actor        Director  Box_Office  Budget  \
# Film
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# Dr. No                 1962  Sean Connery   Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
#
#                        Bond_Actor_Salary
# Film
# Diamonds Are Forever                 5.8
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Never Say Never Again                NaN
# Thunderball                          4.7
# ...

# %%
df.query('Director == "Guy Hamilton" and Actor == "Sean Connery"') #actor in /  python in keyword can also be used for querying
# Out:
#                       Year         Actor      Director  Box_Office  Budget  \
# Film
# Diamonds Are Forever  1971  Sean Connery  Guy Hamilton       442.5    34.7
# Goldfinger            1964  Sean Connery  Guy Hamilton       820.4    18.6
#
#                       Bond_Actor_Salary
# Film
# Diamonds Are Forever                5.8
# Goldfinger                          3.2

# %% [markdown]
# # A Review of the .apply() Method on Single Columns

# %%
def getme(num):
    return str(num) + " Millions"

# %%
df["Budget"].apply(getme)
# Out:
# Film
# A View to a Kill                    54.5 Millions
# Casino Royale                      145.3 Millions
# Casino Royale                       85.0 Millions
# Diamonds Are Forever                34.7 Millions
# Die Another Day                    154.2 Millions
# Dr. No                               7.0 Millions
# For Your Eyes Only                  60.2 Millions
# From Russia with Love               12.6 Millions
# GoldenEye                           76.9 Millions
# Goldfinger                          18.6 Millions
# Licence to Kill                     56.7 Millions
# Live and Let Die                    30.8 Millions
# Moonraker                           91.5 Millions
# Never Say Never Again               86.0 Millions
# Octopussy                           53.9 Millions
# On Her Majesty's Secret Service     37.3 Millions
# Quantum of Solace                  181.4 Millions
# Skyfall                            170.2 Millions
# Spectre                            206.3 Millions
# ...

# %%
columns = ["Box Office", "Budget", "Bond Actor Salary"]

# %%
for col in columns:
    df[col] = df[col].apply(getme)

# %%
df.head()
# Out:
#                       Year           Actor         Director      Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen  275.2 Millions
# Casino Royale         2006    Daniel Craig  Martin Campbell  581.5 Millions
# Casino Royale         1967     David Niven       Ken Hughes  315.0 Millions
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton  442.5 Millions
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori  465.4 Millions
#
#                               Budget Bond Actor Salary
# Film
# A View to a Kill       54.5 Millions      9.1 Millions
# Casino Royale         145.3 Millions      3.3 Millions
# Casino Royale          85.0 Millions      nan Millions
# Diamonds Are Forever   34.7 Millions      5.8 Millions
# Die Another Day       154.2 Millions     17.9 Millions

# %% [markdown]
# # The .apply() Method with Row Values

# %%
def review(row):
    actor = row[1]
    budget = row[4]
    
    if actor == "Pierce Bronsan":
        return "Best"
    elif actor == "Roger Moore":
        return "Enjoyable"
    else:
        return "No Clue"

# %%
df.apply(review, axis = "columns")
# Out:
# Film
# A View to a Kill                   Enjoyable
# Casino Royale                        No Clue
# Casino Royale                        No Clue
# Diamonds Are Forever                 No Clue
# Die Another Day                      No Clue
# Dr. No                               No Clue
# For Your Eyes Only                 Enjoyable
# From Russia with Love                No Clue
# GoldenEye                            No Clue
# Goldfinger                           No Clue
# Licence to Kill                      No Clue
# Live and Let Die                   Enjoyable
# Moonraker                          Enjoyable
# Never Say Never Again                No Clue
# Octopussy                          Enjoyable
# On Her Majesty's Secret Service      No Clue
# Quantum of Solace                    No Clue
# Skyfall                              No Clue
# Spectre                              No Clue
# The Living Daylights                 No Clue
# The Man with the Golden Gun        Enjoyable
# ...

# %% [markdown]
# # The .copy() Method # to copy a slice into another series

# %%
df = pd.read_csv("D:\python\Data Analysis with Python\#Udemy\Pandas\jamesbond.csv", index_col = "Film")
df.sort_index(inplace = True)
df.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
diretcor = df["Director"].copy()

# %%
diretcor.head()
# Out:
# Film
# A View to a Kill              John Glen
# Casino Royale           Martin Campbell
# Casino Royale                Ken Hughes
# Diamonds Are Forever       Guy Hamilton
# Die Another Day            Lee Tamahori
# Name: Director, dtype: object

# %%
diretcor["A View to a Kill"] = "Sir John Glen"

# %%
diretcor.head()
# Out:
# Film
# A View to a Kill          Sir John Glen
# Casino Royale           Martin Campbell
# Casino Royale                Ken Hughes
# Diamonds Are Forever       Guy Hamilton
# Die Another Day            Lee Tamahori
# Name: Director, dtype: object

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------
