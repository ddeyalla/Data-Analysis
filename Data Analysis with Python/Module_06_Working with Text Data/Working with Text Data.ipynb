# %%
import pandas as pd

# %% [markdown]
# # Intro to the Working with Text Data Module

# %%
chicago = pd.read_csv("D:\python\Data Analysis with Python\#Udemy\Pandas\chicago.csv")
chicago["Department"] = chicago["Department"].astype('category')
chicago["Department"] = chicago["Department"].str.title()
chicago["Position Title"] = chicago["Position Title"].str.title()
chicago["Name"] = chicago["Name"].str.title()
chicago.head()
# Out:
#                   Name            Position Title        Department  \
# 0      Aaron,  Elvia J          Water Rate Taker       Water Mgmnt
# 1    Aaron,  Jeffery M            Police Officer            Police
# 2       Aaron,  Karina            Police Officer            Police
# 3  Aaron,  Kimberlei R  Chief Contract Expediter  General Services
# 4  Abad Jr,  Vicente M         Civil Engineer Iv       Water Mgmnt
#
#   Employee Annual Salary
# 0              $90744.00
# 1              $84450.00
# 2              $84450.00
# 3              $89880.00
# 4             $106836.00

# %%
chicago.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32062 entries, 0 to 32061
# Data columns (total 4 columns):
# Name                      32062 non-null object
# Position Title            32062 non-null object
# Department                32062 non-null object
# Employee Annual Salary    32062 non-null float64
# dtypes: float64(1), object(3)
# memory usage: 1.2+ MB

# %%
chicago["Department"].nunique()
# Out:
# 35

# %%
chicago["Department"].count()
# Out:
# 32062

# %%
chicago["Department"] = chicago["Department"].astype('category')

# %% [markdown]
# # Common String Methods - lower, upper, title, and len

# %%
"hello world".upper()
# Out:
# 'HELLO WORLD'

# %%
"HELLO WORLD".lower()
# Out:
# 'hello world'

# %%
"hello world".title()
# Out:
# 'Hello World'

# %%
len("hello world")
# Out:
# 11

# %%
chicago["Department"] = chicago["Department"].str.title()
chicago["Position Title"] = chicago["Position Title"].str.title()
chicago["Name"] = chicago["Name"].str.title()

# %%
chicago.head()
# Out:
#                   Name            Position Title        Department  \
# 0      Aaron,  Elvia J          Water Rate Taker       Water Mgmnt
# 1    Aaron,  Jeffery M            Police Officer            Police
# 2       Aaron,  Karina            Police Officer            Police
# 3  Aaron,  Kimberlei R  Chief Contract Expediter  General Services
# 4  Abad Jr,  Vicente M         Civil Engineer Iv       Water Mgmnt
#
#   Employee Annual Salary
# 0              $90744.00
# 1              $84450.00
# 2              $84450.00
# 3              $89880.00
# 4             $106836.00

# %%
chicago["Department"].str.len().head()
# Out:
# 0    11.0
# 1     6.0
# 2     6.0
# 3    16.0
# 4    11.0
# Name: Department, dtype: float64

# %% [markdown]
# # The .str.replace() Method

# %%
"Hello World".replace(' ', '_') # (WHAT, WHAT TO)
# Out:
# 'Hello_World'

# %%
chicago.dropna(how = 'all', inplace = True)

# %%
chicago.tail()
# Out:
#                       Name                  Position Title        Department  \
# 32057  Zygadlo,  Michael J  Frm Of Machinists - Automotive  General Services
# 32058   Zygowicz,  Peter J                  Police Officer            Police
# 32059    Zymantas,  Mark E                  Police Officer            Police
# 32060  Zyrkowski,  Carlo E                  Police Officer            Police
# 32061  Zyskowski,  Dariusz         Chief Data Base Analyst              Doit
#
#       Employee Annual Salary
# 32057              $99528.00
# 32058              $87384.00
# 32059              $84450.00
# 32060              $87384.00
# 32061             $113664.00

# %%
chicago["Department"] = chicago["Department"].str.replace('Mgmnt', 'Managment')

# %%
chicago.head()
# Out:
#                   Name            Position Title            Department  \
# 0      Aaron,  Elvia J          Water Rate Taker       Water Managment
# 1    Aaron,  Jeffery M            Police Officer                Police
# 2       Aaron,  Karina            Police Officer                Police
# 3  Aaron,  Kimberlei R  Chief Contract Expediter  Generaleral Services
# 4  Abad Jr,  Vicente M         Civil Engineer Iv       Water Managment
#
#   Employee Annual Salary
# 0               90744.00
# 1               84450.00
# 2               84450.00
# 3               89880.00
# 4              106836.00

# %%
chicago["Department"].unique()
# Out:
# array(['Water Managment', 'Police', 'Generaleral Services',
#        'City Council', 'Streets & Sanitation', 'Oemc', 'Aviation', 'Fire',
#        'Family & Support', 'Ipra', 'Public Library', 'Business Affairs',
#        'Transportn', 'Health', "Mayor'S Office", 'Law', 'Finance',
#        'Cultural Affairs', 'Community Development', 'Buildings',
#        'Animal Contrl', 'City Clerk', 'Board Of Election',
#        'Inspector General', 'Treasurer', 'Disabilities',
#        'Human Resources', 'Doit', 'Budget & Managment', 'Procurement',
#        'Human Relations', 'Board Of Ethics', 'Police Board',
#        'Admin Hearng', 'License Appl Comm'], dtype=object)

# %%
chicago["Department"] = chicago["Department"].str.replace('San', 'Sanitation')

chicago["Department"] = chicago["Department"].str.replace('Mgmt', 'Managment')

chicago["Department"] = chicago["Department"].str.replace('Generalral', 'General')

chicago["Department"] = chicago["Department"].str.replace('Gen', 'Genral')

# %%
chicago["Employee Annual Salary"] = chicago["Employee Annual Salary"].str.replace('$', '')

# %%
chicago["Employee Annual Salary"] = chicago["Employee Annual Salary"].astype('float')

# %%
chicago["Employee Annual Salary"].sum()
# Out:
# 2571506375.36

# %%
chicago["Employee Annual Salary"].describe()
# Out:
# count     32062.000000
# mean      80204.178634
# std       25098.329868
# min           0.960000
# 25%       72862.400000
# 50%       84450.000000
# 75%       93240.000000
# max      300000.000000
# Name: Employee Annual Salary, dtype: float64

# %%
chicago["Employee Annual Salary"].nlargest()
# Out:
# 8184     300000.0
# 7954     216210.0
# 25532    202728.0
# 8924     197736.0
# 8042     197724.0
# Name: Employee Annual Salary, dtype: float64

# %% [markdown]
# # Filtering with String Methods / returns Boolean

# %%
chicago[chicago["Position Title"].str.contains("Water")]
# Out:
#                           Name                                 Position Title  \
# 0              Aaron,  Elvia J                               Water Rate Taker
# 554         Aluise,  Vincent G             Foreman Of Water Pipe Construction
# 671            Ander,  Perry A                               Water Chemist Ii
# 685        Anderson,  Andrew J  District Superintendent Of Water Distribution
# 702          Anderson,  Donald             Foreman Of Water Pipe Construction
# 1054          Ashley,  Karma T                               Water Chemist Ii
# 1079         Atkins,  Joanna M                               Water Chemist Ii
# 1181        Azeem,  Mohammed A                               Water Chemist Ii
# 1285            Bajic,  John A                          Water Meter Machinist
# 2400          Bolton,  Brian E                               Water Rate Taker
# 2586           Boyce,  Adner L                               Water Chemist Ii
# ...

# %%
chicago[chicago["Position Title"].str.startswith("Water")]
# Out:
#                           Name               Position Title       Department  \
# 0              Aaron,  Elvia J             Water Rate Taker  Water Managment
# 671            Ander,  Perry A             Water Chemist Ii  Water Managment
# 1054          Ashley,  Karma T             Water Chemist Ii  Water Managment
# 1079         Atkins,  Joanna M             Water Chemist Ii  Water Managment
# 1181        Azeem,  Mohammed A             Water Chemist Ii  Water Managment
# 1285            Bajic,  John A        Water Meter Machinist  Water Managment
# 2400          Bolton,  Brian E             Water Rate Taker  Water Managment
# 2586           Boyce,  Adner L             Water Chemist Ii  Water Managment
# 2745          Brandys,  Daniel             Water Chemist Ii  Water Managment
# 3143          Brown,  Sharon L             Water Rate Taker  Water Managment
# 3246      Buchanan,  Anthony L             Water Chemist Ii  Water Managment
# ...

# %%
chicago[chicago["Position Title"].str.endswith("ist")]
# Out:
#                           Name                          Position Title  \
# 184             Afroz,  Nayyar                            Psychiatrist
# 308           Alarcon,  Luis J              Loan Processing Specialist
# 422           Allain,  Carolyn    Senior Telecommunications Specialist
# 472             Allen,  Robert                               Machinist
# 705        Anderson,  Edward M               Sr Procurement Specialist
# 1022            Arteaga,  Paul                               Machinist
# 1163           Ayala Jr,  Juan             Field Sanitation Specialist
# 1285            Bajic,  John A                   Water Meter Machinist
# 1558       Barrett,  Barbara J           Technical Training Specialist
# 1869        Beltran,  Mauricio                  Procurement Specialist
# 2095        Biggane,  Thomas M                     Security Specialist
# 2319            Bobba,  Mahita              Grants Research Specialist
# ...

# %% [markdown]
# # More String Methods - strip, lstrip, and rstrip / left and right

# %%
"   Hello String".strip()
# Out:
# 'Hello String'

# %%
"   Hello String".lstrip()
# Out:
# 'Hello String'

# %%
"Hello String   ".rstrip()
# Out:
# 'Hello String'

# %% [markdown]
# # String Methods on Index and Columns

# %%
chicago = pd.read_csv("D:\python\Data Analysis with Python\#Udemy\Pandas\chicago.csv", index_col= "Name").dropna(how = 'all')
chicago["Department"] = chicago["Department"].astype('category')
chicago.tail()
# Out:
#                                      Position Title        Department  \
# Name
# ZYGADLO,  MICHAEL J  FRM OF MACHINISTS - AUTOMOTIVE  GENERAL SERVICES
# ZYGOWICZ,  PETER J                   POLICE OFFICER            POLICE
# ZYMANTAS,  MARK E                    POLICE OFFICER            POLICE
# ZYRKOWSKI,  CARLO E                  POLICE OFFICER            POLICE
# ZYSKOWSKI,  DARIUSZ         CHIEF DATA BASE ANALYST              DoIT
#
#                     Employee Annual Salary
# Name
# ZYGADLO,  MICHAEL J              $99528.00
# ZYGOWICZ,  PETER J               $87384.00
# ZYMANTAS,  MARK E                $84450.00
# ZYRKOWSKI,  CARLO E              $87384.00
# ZYSKOWSKI,  DARIUSZ             $113664.00

# %%
chicago.index = chicago.index.str.strip().str.title()

# %%
chicago.columns = chicago.columns.str.upper()

# %%
chicago.tail()
# Out:
#                                      POSITION TITLE        DEPARTMENT  \
# Name
# Zygadlo,  Michael J  FRM OF MACHINISTS - AUTOMOTIVE  GENERAL SERVICES
# Zygowicz,  Peter J                   POLICE OFFICER            POLICE
# Zymantas,  Mark E                    POLICE OFFICER            POLICE
# Zyrkowski,  Carlo E                  POLICE OFFICER            POLICE
# Zyskowski,  Dariusz         CHIEF DATA BASE ANALYST              DoIT
#
#                     EMPLOYEE ANNUAL SALARY
# Name
# Zygadlo,  Michael J              $99528.00
# Zygowicz,  Peter J               $87384.00
# Zymantas,  Mark E                $84450.00
# Zyrkowski,  Carlo E              $87384.00
# Zyskowski,  Dariusz             $113664.00

# %% [markdown]
# # Split Strings by Characters with .str.split() Method

# %%
chicago.head()
# Out:
#                   Name            Position Title        Department  \
# 0      Aaron,  Elvia J          Water Rate Taker       Water Mgmnt
# 1    Aaron,  Jeffery M            Police Officer            Police
# 2       Aaron,  Karina            Police Officer            Police
# 3  Aaron,  Kimberlei R  Chief Contract Expediter  General Services
# 4  Abad Jr,  Vicente M         Civil Engineer Iv       Water Mgmnt
#
#   Employee Annual Salary
# 0              $90744.00
# 1              $84450.00
# 2              $84450.00
# 3              $89880.00
# 4             $106836.00

# %%
"Hello My name is Divyanshu".split(" ") #("Delimiter")
# Out:
# ['Hello', 'My', 'name', 'is', 'Divyanshu']

# %%
chicago["Name"].str.split(",").str.get(0).value_counts()
# Out:
# Williams         293
# Johnson          244
# Smith            241
# Brown            185
# Jones            183
# Rodriguez        171
# Jackson          136
# Garcia           130
# Davis            127
# Hernandez        110
# Martinez         108
# Lopez            106
# Gonzalez         104
# Perez            100
# Wilson            94
# Rivera            90
# Thomas            89
# Anderson          82
# Torres            81
# Murphy            80
# Robinson          79
# Moore             78
# Sanchez           76
# Harris            76
# Miller            75
# Lewis             74
# Taylor            73
# Martin            72
# Clark             66
# White             66
#                 ...
# Dziennik Jr        1
# White Sr           1
# Pema               1
# Gatton Jr          1
# Monestero          1
# Udell              1
# Lasch              1
# Van Den Bosch      1
# Senderak           1
# Limon              1
# Sumpter            1
# Simms              1
# ...

# %%
chicago["Position Title"].str.split(" ").str.get(0).value_counts()
# Out:
# Police                   10856
# Firefighter-Emt           1509
# Sergeant                  1186
# Pool                       918
# Firefighter                810
# Crossing                   775
# Motor                      721
# Sanitation                 715
# Paramedic                  641
# Asst                       606
# Traffic                    512
# Fire                       512
# Senior                     470
# Construction               452
# Lieutenant-Emt             394
# Administrative             375
# Library                    365
# Librarian                  335
# Lieutenant                 332
# Operating                  324
# Electrical                 313
# Aviation                   309
# Firefighter/Paramedic      259
# General                    257
# Staff                      250
# Clerk                      242
# Foreman                    237
# Hoisting                   214
# Deputy                     213
# Machinist                  210
# ...

# %% [markdown]
# # More Practice with Splits

# %%
chicago["Name"].str.split(",").str.get(1).str.strip().str.split(" ").str.get(0).value_counts().head()
# Out:
# Michael    1153
# John        899
# James       676
# Robert      622
# Joseph      537
# Name: Name, dtype: int64

# %% [markdown]
# # The expand and n Parameters of the .str.split() Method

# %%
chicago[["First Name", "Last Name"]] = chicago["Name"].str.split(",", expand = True)

# %%
chicago.head()
# Out:
#                   Name            Position Title        Department  \
# 0      Aaron,  Elvia J          Water Rate Taker       Water Mgmnt
# 1    Aaron,  Jeffery M            Police Officer            Police
# 2       Aaron,  Karina            Police Officer            Police
# 3  Aaron,  Kimberlei R  Chief Contract Expediter  General Services
# 4  Abad Jr,  Vicente M         Civil Engineer Iv       Water Mgmnt
#
#   Employee Annual Salary First Name      Last Name First Title  \
# 0              $90744.00      Aaron        Elvia J       Water
# 1              $84450.00      Aaron      Jeffery M      Police
# 2              $84450.00      Aaron         Karina      Police
# 3              $89880.00      Aaron    Kimberlei R       Chief
# 4             $106836.00    Abad Jr      Vicente M       Civil
#
#          Second Title
# 0          Rate Taker
# 1             Officer
# 2             Officer
# 3  Contract Expediter
# 4         Engineer Iv

# %%
chicago[["First Title", "Second Title"]] = chicago["Position Title"].str.split(" ", expand = True, n = 1)

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------
